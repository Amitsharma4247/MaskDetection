# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/dataset.zip' /content/

# %%
# !unzip '/content/dataset.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/train/images/3870.png
#   inflating: /content/dataset/train/images/3871.png
#   inflating: /content/dataset/train/images/3874.png
#   inflating: /content/dataset/train/images/3879.png
#   inflating: /content/dataset/train/images/3880.png
#   inflating: /content/dataset/train/images/3881.png
#   inflating: /content/dataset/train/images/3882.png
#   inflating: /content/dataset/train/images/3884.png
#   inflating: /content/dataset/train/images/3886.png
#   inflating: /content/dataset/train/images/3887.png
#   inflating: /content/dataset/train/images/3888.png
#   inflating: /content/dataset/train/images/3891.png
#   inflating: /content/dataset/train/images/3894.png
#   inflating: /content/dataset/train/images/3895.png
#   inflating: /content/dataset/train/images/3897.png
#   inflating: /content/dataset/train/images/3898.png
#   inflating: /content/dataset/train/images/3899.png
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.6/780.6 kB 8.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo detect train data='/content/drive/MyDrive/data.yaml' model=yolov8x.pt epochs=90 imgsz=320 project =' /content/training_results' name = target_roi
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 445MB/s]
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp /content/training_results/target_roi/weights/best.pt "/content/drive/MyDrive/ProjectMaskDetection"

# %%
# !yolo task=detect mode=predict model= /content/drive/MyDrive/ProjectMaskDetection/best.pt source = /content/0001.jpg show=True imgsz=320 name=yolov8n_v8_50e_infer1280
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68142828 parameters, 0 gradients, 257.5 GFLOPs
#
# image 1/1 /content/0001.jpg: 192x320 1 face_other_covering, 2 hats, 1 hood, 157.6ms
# Speed: 2.8ms preprocess, 157.6ms inference, 1158.2ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs/detect/yolov8n_v8_50e_infer1280
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !cp -r /content/runs/detect/yolov8n_v8_50e_infer12806/ "/content/drive/MyDrive/test_yolov8m/"
# Out:
# cp: cannot stat '/content/runs/detect/yolov8n_v8_50e_infer12806/': No such file or directory

# %%
# !yolo export model=/content/drive/MyDrive/ProjectMaskDetection/best.pt format="openvino" imgsz = 320 half = True
# Out:
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 268 layers, 68142828 parameters, 0 gradients, 257.5 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/ProjectMaskDetection/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 24, 2100) (130.4 MB)
# requirements: Ultralytics requirement ['openvino>=2024.0.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.7/38.7 MB 219.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.9s, installed 1 package: ['openvino>=2024.0.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# OpenVINO: starting export with openvino 2024.1.0-15008-f4afc983258-releases/2024/1...
# OpenVINO: export success ✅ 17.5s, saved as '/content/drive/MyDrive/ProjectMaskDetection/best_openvino_model/' (130.4 MB)
#
# Export complete (22.8s)
# Results saved to /content/drive/MyDrive/ProjectMaskDetection
# ...
